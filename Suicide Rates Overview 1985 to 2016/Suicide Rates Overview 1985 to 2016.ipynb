# %% [markdown]
# # Suicide Rates Overview 1985 to 2016

# %% [markdown]
# ## Compares socio-economic info with suicide rates by year and country
#
# [Kaggle](https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the dataset file
df = pd.read_csv("data/master.csv")

# %%
# Displaying the first 5 rows of the DataFram
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
# Data type in each column
df.dtypes
# Out:
# country                object
# year                    int64
# sex                    object
# age                    object
# suicides_no             int64
# population              int64
# suicides/100k pop     float64
# country-year           object
# HDI for year          float64
#  gdp_for_year ($)      object
# gdp_per_capita ($)      int64
# generation             object
# dtype: object

# %%
# Summary of information in all columns
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
# Number of rows and columns in the DataFrame
print('Number of rows:', df.shape[0])
print('Number of columns:', df.shape[1])
# Out:
# Number of rows: 27820
# Number of columns: 12

# %%
analysis_max_gdp_per_capita = df[df['gdp_per_capita ($)'] == 126352.000000]

# %%
analysis_max_gdp_per_capita
# Out:
#           country  year     sex          age  suicides_no  population  \
# 15654  Luxembourg  2014    male  55-74 years           18       52295
# 15655  Luxembourg  2014    male    75+ years            4       14546
# 15656  Luxembourg  2014    male  35-54 years           20       88218
# 15657  Luxembourg  2014    male  25-34 years            7       41442
# 15658  Luxembourg  2014  female    75+ years            3       22669
# 15659  Luxembourg  2014  female  55-74 years            5       52260
# 15660  Luxembourg  2014  female  15-24 years            2       32510
# 15661  Luxembourg  2014    male  15-24 years            2       34219
# 15662  Luxembourg  2014  female  25-34 years            2       40862
# 15663  Luxembourg  2014  female  35-54 years            3       84147
# 15664  Luxembourg  2014    male   5-14 years            1       31718
# 15665  Luxembourg  2014  female   5-14 years            0       30054
#
# ...

# %%
analysis_max_gdp_per_capita["suicides_no"].
# Out:
# 67

# %%
df.query("country == 'Luxembourg'")
# Out:
#           country  year     sex          age  suicides_no  population  \
# 15306  Luxembourg  1985    male    75+ years            6        6900
# 15307  Luxembourg  1985    male  55-74 years           14       30200
# 15308  Luxembourg  1985  female    75+ years            4       13500
# 15309  Luxembourg  1985    male  35-54 years           12       50200
# 15310  Luxembourg  1985  female  25-34 years            6       29800
# 15311  Luxembourg  1985  female  35-54 years            5       47900
# 15312  Luxembourg  1985    male  25-34 years            3       29900
# 15313  Luxembourg  1985    male   5-14 years            2       21700
# 15314  Luxembourg  1985    male  15-24 years            2       28100
# 15315  Luxembourg  1985  female  15-24 years            1       27800
# 15316  Luxembourg  1985  female   5-14 years            0       20500
# 15317  Luxembourg  1985  female  55-74 years            0       38300
# ...
